# %%
from obspy import read

# %%
st = read('AoA50.H1')

# %%
print(st)
# Out:
# 1 Trace(s) in Stream:
# .AoA50..H1 | 2016-09-24T00:00:00.000000Z - 2016-09-24T23:59:59.995000Z | 200.0 Hz, 17280000 samples

# %%
len(st)
# Out:
# 1

# %%
tr = st[0]

# %%
print(tr)
# Out:
# .AoA50..H1 | 2016-09-24T00:00:00.000000Z - 2016-09-24T23:59:59.995000Z | 200.0 Hz, 17280000 samples

# %%
from obspy.core import read

# %%
singlechanel = read('AoA50.H1')

# %%
print(singlechanel)
# Out:
# 1 Trace(s) in Stream:
# .AoA50..H1 | 2016-09-24T00:00:00.000000Z - 2016-09-24T23:59:59.995000Z | 200.0 Hz, 17280000 samples

# %%
singlechanel.plot()

# %%
#singlechanel.plot(type='dayplot')

# %%
#from obspy import read

# %%
#st = read('AoA50.H1')

# %%
#st.filter("lowpass", freq=0.1, corners=2)
# Out:
# 1 Trace(s) in Stream:
# .AoA50..H1 | 2016-09-24T00:00:00.000000Z - 2016-09-24T23:59:59.995000Z | 200.0 Hz, 17280000 samples

# %%
#st.plot(type="dayplot", interval=60, right_vertical_labels=False,
        vertical_scaling_range=5e3, one_tick_per_line=True,
        color=['k', 'r', 'g' 'b'], show_y_UTC_label=False,
        events={'min_magnitude': 6.5})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('gb', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-56514aa3351c> in <module>
#       2         vertical_scaling_range=5e3, one_tick_per_line=True,
#       3         color=['k', 'r', 'g' 'b'], show_y_UTC_label=False,
# ----> 4         events={'min_magnitude': 6.5})
#
# ~/Applications/obspy/obspy/core/stream.py in plot(self, *args, **kwargs)
#    1159         from obspy.imaging.waveform import WaveformPlotting
# ...
